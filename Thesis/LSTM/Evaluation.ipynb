# %%
from utils import load_for_evaluation, compare_models

# %%
models = [
    "baseline",
    "class_weights"



]
models_data = [load_for_evaluation(name) for name in models]
# Out:
# 2024-07-26 12:15:20.093151: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Max
# 2024-07-26 12:15:20.093171: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-07-26 12:15:20.093174: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-07-26 12:15:20.093187: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-26 12:15:20.093197: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model loaded from ../models/lstm/baseline/baseline.h5
# Data loaded successfully
# Model loaded from ../models/lstm/class_weights/class_weights.h5
# Data loaded successfully

# %%
compare_models(models_data)
# Out:
# 2024-07-26 12:15:20.906620: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step
