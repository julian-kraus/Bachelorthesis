# %%
from utils import load_for_evaluation, compare_models

# %%
models = [
    "final_small",
    "no_bi_lstm",



]
models_data = [load_for_evaluation(name) for name in models]
# Out:
# 2024-08-11 19:28:49.773268: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Max
# 2024-08-11 19:28:49.773303: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-08-11 19:28:49.773310: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-08-11 19:28:49.773329: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-08-11 19:28:49.773343: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model loaded from ../models/lstm/final_small/final_small.h5
# Data loaded successfully
# Model loaded from ../models/lstm/no_bi_lstm/no_bi_lstm.h5
# ...

# %%
compare_models(models_data)
# Out:
# 2024-08-11 19:28:52.182223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step

# %%
import pickle
import pandas as pd
model_type = 'lstm'
model_name = 'final_small'
history_path = f'../data/{model_type}/{model_name}/{model_name}_history.pkl'

    # Load the history
with open(history_path, 'rb') as file:
    history = pickle.load(file)
history_df = pd.DataFrame(history.history)
history_df.to_csv('final_training_history.csv', index=False)
