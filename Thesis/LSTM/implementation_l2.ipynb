# %%
import os
import pandas as pd
import tensorflow as tf
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Bidirectional, Conv1D, GlobalMaxPooling1D, Concatenate, AdditiveAttention
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import AdditiveAttention
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from utils import eval, eval_training, get_train_test_data, save_for_evaluation, process_train_test_data
import re
import numpy as np
import spacy
from gensim.models import Word2Vec
from transformers import BertTokenizer, TFBertModel


os.environ['TF_NUM_INTEROP_THREADS'] = '10'
os.environ['TF_NUM_INTRAOP_THREADS'] = '10'

# Configure TensorFlow session for multi-threading
tf.config.threading.set_inter_op_parallelism_threads(10)
tf.config.threading.set_intra_op_parallelism_threads(10)
# Ensure TensorFlow is using the Metal backend
gpu = len (tf.config.list_physical_devices ('GPU'))>0
print ("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# GPU is available

# %% [markdown]
# # Data preparation

# %%
data_label = "data"
predict_label = "label"
balanced = False
labels = None
class_weights = False
sample_weights = False
df_train = pd.read_csv('../data/data_train.csv')
df_valid = pd.read_csv('../data/data_valid.csv')
df_test = pd.read_csv('../data/data_test.csv')

train_padded, valid_padded, test_padded, train_labels, valid_labels, test_labels, label_encoder, num_classes, max_length, word_index, class_weights, sample_weights = process_train_test_data(df_train, df_valid, df_test, data_label, predict_label, lables=labels, class_weights=class_weights, sample_weights=sample_weights)
# Out:
# label
# other-minor                 9805
# meniskus-urgent             9312
# cruciate-ligament-urgent    2388
# meniskus-minor              1664
# cruciate-ligament-minor      355
# Name: count, dtype: int64

# %% [markdown]
# # Model parameters

# %%
model_name = "l2"

# %%
from utils import get_standard_parameters

optimizer, loss, metrics, early_stopping_callback, embedding_dim, lstm_units, epochs, batch_size = get_standard_parameters()
# Out:
# 2024-07-26 11:50:41.149607: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Max
# 2024-07-26 11:50:41.149654: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 64.00 GB
# 2024-07-26 11:50:41.149672: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 24.00 GB
# 2024-07-26 11:50:41.149701: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-26 11:50:41.149732: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# # Model definition and training

# %%
from tensorflow.keras.regularizers import l2

# Define the input layer
input_text = Input(shape=(max_length,), dtype='int32', name='text_input')

# Embedding layer
embedding = Embedding(input_dim=len(word_index), output_dim=embedding_dim)(input_text)

# Two LSTM layers with L2 regularization
x = Bidirectional(LSTM(units=lstm_units, return_sequences=True, kernel_regularizer=l2(0.004)))(embedding)
x = Bidirectional(LSTM(units=lstm_units, kernel_regularizer=l2(0.004)))(x)

# Output layer
output = Dense(num_classes, activation='softmax', kernel_regularizer=l2(0.004))(x)

# Define the model
model = Model(inputs=input_text, outputs=output)

# Compile the model
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
history = model.fit(train_padded, train_labels, epochs=epochs, batch_size=batch_size,
                    validation_data=(valid_padded, valid_labels), callbacks=[early_stopping_callback])
# Out:
# Epoch 1/15
# 2024-07-26 11:50:41.923303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 125s 167ms/step - accuracy: 0.4464 - auc: 0.8040 - f1_score: 0.2246 - loss: 1.8628 - val_accuracy: 0.4884 - val_auc: 0.8330 - val_f1_score: 0.2675 - val_loss: 1.1382
# Epoch 2/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 112s 152ms/step - accuracy: 0.5715 - auc: 0.8623 - f1_score: 0.3404 - loss: 1.0599 - val_accuracy: 0.5652 - val_auc: 0.8597 - val_f1_score: 0.3316 - val_loss: 1.0706
# Epoch 3/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 122s 166ms/step - accuracy: 0.6387 - auc: 0.8880 - f1_score: 0.3853 - loss: 0.9694 - val_accuracy: 0.5861 - val_auc: 0.8639 - val_f1_score: 0.3391 - val_loss: 1.0633
# Epoch 4/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 121s 164ms/step - accuracy: 0.6755 - auc: 0.9037 - f1_score: 0.4074 - loss: 0.9023 - val_accuracy: 0.6025 - val_auc: 0.8726 - val_f1_score: 0.3631 - val_loss: 1.0519
# Epoch 5/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 120s 163ms/step - accuracy: 0.6963 - auc: 0.9153 - f1_score: 0.4246 - loss: 0.8501 - val_accuracy: 0.5844 - val_auc: 0.8612 - val_f1_score: 0.3530 - val_loss: 1.0874
# Epoch 6/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 120s 162ms/step - accuracy: 0.7130 - auc: 0.9224 - f1_score: 0.4352 - loss: 0.8150 - val_accuracy: 0.6190 - val_auc: 0.8805 - val_f1_score: 0.3719 - val_loss: 1.0072
# Epoch 7/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 123s 167ms/step - accuracy: 0.7317 - auc: 0.9332 - f1_score: 0.4475 - loss: 0.7620 - val_accuracy: 0.6273 - val_auc: 0.8784 - val_f1_score: 0.3743 - val_loss: 1.0462
# Epoch 8/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 120s 163ms/step - accuracy: 0.7407 - auc: 0.9378 - f1_score: 0.4550 - loss: 0.7365 - val_accuracy: 0.6176 - val_auc: 0.8671 - val_f1_score: 0.3730 - val_loss: 1.1003
# Epoch 9/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 260s 353ms/step - accuracy: 0.7499 - auc: 0.9421 - f1_score: 0.4671 - loss: 0.7117 - val_accuracy: 0.6257 - val_auc: 0.8777 - val_f1_score: 0.3802 - val_loss: 1.0732
# Epoch 10/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 117s 159ms/step - accuracy: 0.7583 - auc: 0.9478 - f1_score: 0.4862 - loss: 0.6768 - val_accuracy: 0.6166 - val_auc: 0.8736 - val_f1_score: 0.3778 - val_loss: 1.0652
# Epoch 11/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 121s 164ms/step - accuracy: 0.7713 - auc: 0.9515 - f1_score: 0.5096 - loss: 0.6534 - val_accuracy: 0.6232 - val_auc: 0.8785 - val_f1_score: 0.3889 - val_loss: 1.0500
# Epoch 12/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 121s 165ms/step - accuracy: 0.7734 - auc: 0.9533 - f1_score: 0.5301 - loss: 0.6428 - val_accuracy: 0.6347 - val_auc: 0.8813 - val_f1_score: 0.4013 - val_loss: 1.0333
# Epoch 13/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 122s 166ms/step - accuracy: 0.7830 - auc: 0.9572 - f1_score: 0.5417 - loss: 0.6173 - val_accuracy: 0.6279 - val_auc: 0.8779 - val_f1_score: 0.4218 - val_loss: 1.0889
# Epoch 14/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 123s 167ms/step - accuracy: 0.7790 - auc: 0.9569 - f1_score: 0.5458 - loss: 0.6223 - val_accuracy: 0.6380 - val_auc: 0.8786 - val_f1_score: 0.4275 - val_loss: 1.0845
# Epoch 15/15
# 736/736 ━━━━━━━━━━━━━━━━━━━━ 124s 168ms/step - accuracy: 0.7862 - auc: 0.9607 - f1_score: 0.5643 - loss: 0.5966 - val_accuracy: 0.6366 - val_auc: 0.8835 - val_f1_score: 0.4488 - val_loss: 1.0453
# Restoring model weights from the end of the best epoch: 15.

# %%
save_for_evaluation(model, history, model_name, test_padded, test_labels, label_encoder)
# Out:
# Model saved to ../models/lstm/l2/l2.h5
# Data saved

# %%
eval_training(history, metrics)

# %%
eval(model, test_padded, test_labels, label_encoder)
# Out:
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step
