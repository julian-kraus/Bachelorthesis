# %%
from utils import load_for_evaluation, compare_models

# %%
models = [
    "baseline",
    "dropout_less",
    "dropout_more"



]
models_data = [load_for_evaluation(name) for name in models]
# Out:
# Model loaded from ../models/lstm/baseline/baseline.h5
# Data loaded successfully
# Model loaded from ../models/lstm/dropout_less/dropout_less.h5
# Data loaded successfully
# Model loaded from ../models/lstm/dropout_more/dropout_more.h5
# Data loaded successfully

# %%
compare_models(models_data)
# Out:
# 2024-07-26 11:46:39.277011: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step
