# %%
import os
import pandas as pd
import tensorflow as tf
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout, Bidirectional, Conv1D, GlobalMaxPooling1D, Concatenate, AdditiveAttention
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import AdditiveAttention
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from utils import eval, eval_training, get_train_test_data, save_for_evaluation, process_train_test_data
import re
import numpy as np
import spacy
from gensim.models import Word2Vec
from transformers import BertTokenizer, TFBertModel


os.environ['TF_NUM_INTEROP_THREADS'] = '10'
os.environ['TF_NUM_INTRAOP_THREADS'] = '10'

# Configure TensorFlow session for multi-threading
tf.config.threading.set_inter_op_parallelism_threads(10)
tf.config.threading.set_intra_op_parallelism_threads(10)
# Ensure TensorFlow is using the Metal backend
gpu = len (tf.config.list_physical_devices ('GPU'))>0
print ("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# GPU is available

# %% [markdown]
# # Data preparation

# %%
data_label = "data"
predict_label = "label"
balanced = False
labels = None
class_weights = False
sample_weights = False
df_train = pd.read_csv('../data/data_train.csv')
df_valid = pd.read_csv('../data/data_valid.csv')
df_test = pd.read_csv('../data/data_test.csv')

train_padded, valid_padded, test_padded, train_labels, valid_labels, test_labels, label_encoder, num_classes, max_length, word_index, class_weights, sample_weights = process_train_test_data(df_train, df_valid, df_test, data_label, predict_label, lables=labels, class_weights=class_weights, sample_weights=sample_weights)
# Out:
# label
# other-minor                 9633
# meniskus-urgent             9185
# cruciate-ligament-urgent    2377
# meniskus-minor              1657
# cruciate-ligament-minor      354
# Name: count, dtype: int64

# %% [markdown]
# # Model parameters

# %%
df_train = df_train.dropna(subset=['data'])
df_valid = df_valid.dropna(subset=['data'])
df_test = df_test.dropna(subset=['data'])

# %%
print(df_train["data"].iloc[1])
# Out:
# 35.0 Jahre alt männlich Geht sehr gut nach LCA-Plastik. Score liegt bei alex. Mein Knie hat einen geringen Erguß und es gibt Schmerzen auf der medialen Seite des Kniegelenks.

# %%
#model_name = "final_batch"

# %%
from utils import get_standard_parameters

optimizer, loss, metrics, early_stopping_callback, embedding_dim, lstm_units, epochs, batch_size = get_standard_parameters()

# %%
from tensorflow.keras.callbacks import Callback
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('val_loss'))

loss_history = LossHistory()

# %% [markdown]
# # Model definition and training

# %%
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, GlobalAveragePooling1D, MaxPooling1D
from tensorflow.keras.layers import Attention, Flatten, BatchNormalization, Bidirectional, LSTM, Dropout, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding

# Define the input layer
input_text = Input(shape=(max_length,), dtype='int32', name='text_input')

# Embedding layer
embedding = Embedding(input_dim=len(word_index), output_dim=embedding_dim)(input_text)

# Two LSTM layers with L2 regularization

x = Conv1D(filters=512, kernel_size=50, activation='relu')(embedding) # was 25
x = MaxPooling1D(pool_size=25)(x)
x = BatchNormalization()(x)
x = Bidirectional(LSTM(units=718, return_sequences=True))(x) # 512

# Applying Attention Mechanism
query, value = x, x
attention = Attention()([query, value])
x = Flatten()(attention)

x = Dense(units=128, activation='relu')(x)

# Output layer
output = Dense(num_classes, activation='softmax')(x)

# Define the model
model = Model(inputs=input_text, outputs=output)

# Compile the model
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
history = model.fit(train_padded, train_labels, epochs=50, batch_size=96,
                    validation_data=(valid_padded, valid_labels), callbacks=[early_stopping_callback])
# Out:
# Epoch 1/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 118s 480ms/step - accuracy: 0.4590 - auc: 0.7966 - f1_score: 0.2204 - loss: 1.2388 - val_accuracy: 0.4221 - val_auc: 0.7727 - val_f1_score: 0.2431 - val_loss: 1.3167
# Epoch 2/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 275s 1s/step - accuracy: 0.6319 - auc: 0.8884 - f1_score: 0.3968 - loss: 0.9359 - val_accuracy: 0.5401 - val_auc: 0.8608 - val_f1_score: 0.3363 - val_loss: 1.0560
# Epoch 3/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 212s 874ms/step - accuracy: 0.8166 - auc: 0.9671 - f1_score: 0.6552 - loss: 0.5046 - val_accuracy: 0.6790 - val_auc: 0.9141 - val_f1_score: 0.5485 - val_loss: 0.8316
# Epoch 4/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 195s 805ms/step - accuracy: 0.9102 - auc: 0.9904 - f1_score: 0.8632 - loss: 0.2606 - val_accuracy: 0.6396 - val_auc: 0.8913 - val_f1_score: 0.4962 - val_loss: 1.0652
# Epoch 5/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 204s 842ms/step - accuracy: 0.9327 - auc: 0.9952 - f1_score: 0.9038 - loss: 0.1816 - val_accuracy: 0.7431 - val_auc: 0.9171 - val_f1_score: 0.6636 - val_loss: 1.0266
# Epoch 6/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 199s 823ms/step - accuracy: 0.9568 - auc: 0.9977 - f1_score: 0.9452 - loss: 0.1188 - val_accuracy: 0.4547 - val_auc: 0.7649 - val_f1_score: 0.4438 - val_loss: 2.5138
# Epoch 7/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 201s 831ms/step - accuracy: 0.9617 - auc: 0.9983 - f1_score: 0.9537 - loss: 0.1031 - val_accuracy: 0.7291 - val_auc: 0.9150 - val_f1_score: 0.6540 - val_loss: 1.0523
# Epoch 8/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 200s 825ms/step - accuracy: 0.9656 - auc: 0.9984 - f1_score: 0.9565 - loss: 0.0930 - val_accuracy: 0.7157 - val_auc: 0.9041 - val_f1_score: 0.6855 - val_loss: 1.2553
# Epoch 9/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 201s 832ms/step - accuracy: 0.9677 - auc: 0.9986 - f1_score: 0.9656 - loss: 0.0872 - val_accuracy: 0.7339 - val_auc: 0.8985 - val_f1_score: 0.6913 - val_loss: 1.5548
# Epoch 10/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 200s 828ms/step - accuracy: 0.9737 - auc: 0.9990 - f1_score: 0.9700 - loss: 0.0721 - val_accuracy: 0.7261 - val_auc: 0.9056 - val_f1_score: 0.6556 - val_loss: 1.2985
# Epoch 11/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 201s 830ms/step - accuracy: 0.9725 - auc: 0.9987 - f1_score: 0.9596 - loss: 0.0743 - val_accuracy: 0.7394 - val_auc: 0.8964 - val_f1_score: 0.7007 - val_loss: 1.5126
# Epoch 12/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 200s 828ms/step - accuracy: 0.9781 - auc: 0.9990 - f1_score: 0.9745 - loss: 0.0589 - val_accuracy: 0.6789 - val_auc: 0.8745 - val_f1_score: 0.5974 - val_loss: 1.7412
# Epoch 13/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 199s 825ms/step - accuracy: 0.9811 - auc: 0.9992 - f1_score: 0.9772 - loss: 0.0531 - val_accuracy: 0.7313 - val_auc: 0.8917 - val_f1_score: 0.6964 - val_loss: 1.6021
# Epoch 14/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 201s 830ms/step - accuracy: 0.9808 - auc: 0.9995 - f1_score: 0.9787 - loss: 0.0503 - val_accuracy: 0.7498 - val_auc: 0.9042 - val_f1_score: 0.7074 - val_loss: 1.5127
# Epoch 15/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 199s 824ms/step - accuracy: 0.9800 - auc: 0.9994 - f1_score: 0.9752 - loss: 0.0523 - val_accuracy: 0.6904 - val_auc: 0.8854 - val_f1_score: 0.6372 - val_loss: 1.5870
# Epoch 16/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 136s 563ms/step - accuracy: 0.9799 - auc: 0.9994 - f1_score: 0.9735 - loss: 0.0521 - val_accuracy: 0.7203 - val_auc: 0.8826 - val_f1_score: 0.6871 - val_loss: 1.6921
# Epoch 17/50
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 132s 546ms/step - accuracy: 0.9799 - auc: 0.9994 - f1_score: 0.9727 - loss: 0.0503 - val_accuracy: 0.6698 - val_auc: 0.8623 - val_f1_score: 0.6108 - val_loss: 1.9105
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
eval_training(history, metrics)

# %%
eval(model, test_padded, test_labels, label_encoder)
# Out:
# 242/242 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 eval(model, test_padded, test_labels, label_encoder)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Uni/Semester 8/Bachelorarbeit/Repo/Bachelorthesis/Thesis/LSTM/utils.py:154, in eval(model, test_padded, test_labels, label_encoder, model_name, conf)
#     151     plt.show()
#     153 # Visualize the model
# --> 154  plot_model(model, to_file='../reports/' + model_type + '/' + model_name + '.png', show_layer_activations=True)
#     155  return min_report
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tf2/lib/python3.10/site-packages/keras/src/utils/model_visualization.py:477, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     474 try:
#     475     from IPython import display
# --> 477     return display.Image(filename=to_file)
#     478 except ImportError:
#     479     pass
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/tf2/lib/python3.10/site-packages/IPython/core/display.py:961, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     958 self.embed = embed if embed is not None else (url is None)
#     960 if self.embed and self.format not in self._ACCEPTABLE_EMBEDDINGS:
# --> 961     raise ValueError("Cannot embed the '%s' image format" % (self.format))
#     962 if self.embed:
#     963     self._mimetype = self._MIMETYPES.get(self.format)
#
# ValueError: Cannot embed the '../reports/lstm/.png' image format

# %%
losses = list(filter(lambda item: item is not None, loss_history.losses))
plt.figure(figsize=(10, 6))
plt.hist(losses, bins=50, alpha=0.75, color='blue')
plt.title('Distribution of Losses')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.show()
print(loss_history.losses)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, Non ...

# %%
# Function to calculate loss per sample
def calculate_loss_per_sample(model, x, y):
    predictions = model.predict(x)
    loss_fn = tf.keras.losses.CategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)
    losses = loss_fn(y, predictions)
    return losses.numpy()

# Calculate losses for each sample
sample_losses = calculate_loss_per_sample(model, valid_padded, valid_labels)

# Find indices of the highest losses
num_problematic = 10  # Number of problematic samples to identify
problematic_indices = np.argsort(sample_losses)[-num_problematic:]

# Print the most problematic samples
print("Indices of most problematic samples:", problematic_indices)
print("Loss values of most problematic samples:", sample_losses[problematic_indices])
plt.figure(figsize=(10, 6))
plt.hist(sample_losses, bins=50, alpha=0.75, color='blue')
plt.title('Distribution of Losses')
plt.xlabel('Loss')
plt.ylabel('Frequency')
plt.show()
# Out:
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 15s 61ms/step
# Indices of most problematic samples: [6303 6355 5831 1893 6559 2240 7715 4645 5312 4432]
# Loss values of most problematic samples: [16.118095 16.118095 16.118095 16.118095 16.118095 16.118095 16.118095
#  16.118095 16.118095 16.118095]

# %%
# Optional: Analyze the problematic samples
for index in problematic_indices:
    print(f"Sample {index} - Features: {df_train.iloc[index]['data']}, Label: {label_encoder.inverse_transform([np.argmax(train_labels[index])])}, Loss: {sample_losses[index]}")
# Out:
# Sample 6303 - Features: 26.0 Jahre alt weiblich Pat stellt sich heute mit den kompletten Unterlagen vor.. Mein rechtes Knie hat keine Schwellung, keine Rötung und auch keine Überstreckung oder Streckdefizite. Die Beugung des Knies ist gut möglich., Label: ['meniskus-urgent'], Loss: 16.11809539794922
# Sample 6355 - Features: 20.0 Jahre alt männlich Vor 5 Monaten beim Fußball mit li. Fuß in Kunstrasen hängengeblieben und dabei das linke Knie verdreht; Knallgeräusch gehhört. Seither zwischendurch Schwellung und wegknickereignisse. Pat. stellt sich mit MRT Bildern vor. Subj. Instabilitätsgefühl ca. 5 x givingway Ereignisse. Mein linkes Bein ist gerade, und mein Gangbild ist flüssig. Mein Knie ist nicht überstreckt, und es gibt kein Streckdefizit. Die Beugung des Knies ist gut möglich, und es gibt keine Schwellung. Es gibt Schmerzen an der inneren Seite des Knies, wenn man darauf drückt. Es gibt keinen Schmerz an der Kniescheibenspitze oder an der Kante der Kniescheibe., Label: ['other-minor'], Loss: 16.11809539794922
# Sample 5831 - Features: . Mein Gangbild ist flüssig, und ich kann das rechte Knie überstrecken. Es gibt kein Streckdefizit des Knies. Die Beugung des Knies ist gut möglich. Klinisch gibt es keine Schwellung. Es gibt einen mäßigen Druckschmerz an der Spitze der Kniescheibe und Schmerzen auf der inneren Seite des Kniegelenks., Label: ['meniskus-urgent'], Loss: 16.11809539794922
# Sample 1893 - Features: 34.0 Jahre alt männlich Insges. deutliche Besserungstendenz; noch Restbeschwerden; zeitweise Belastungsschmerz; seit 3 Tagen diffuser Knieschmerz. Mein linkes Knie kann beugen und strecken, aber es ist nicht möglich, es zu überstrecken. Es gibt kein Streckdefizit, aber die Beugung des Knies ist eingeschränkt., Label: ['meniskus-urgent'], Loss: 16.11809539794922
# Sample 6559 - Features: 41.0 Jahre alt weiblich geht nicht so gut; von Dr. Lichthardt 3x punktiert. Mein Knie hat einen Erguß, und ich kann es überstrecken. Es gibt kein Streckdefizit, aber die Beugung ist eingeschränkt., Label: ['other-minor'], Loss: 16.11809539794922
# Sample 2240 - Features: 26.0 Jahre alt männlich Am 03.04.2014 beim privaten Fußballspielen beim Landen nach einem Kopfball das rechte Knie verdreht bei feststehendem Fuß. Subj. Schwellneigung im Anschluss. Vorstellung in der Notaufnahme in Mechernich mit Frakturausschluss. Vorstellung bei Dr. Reintke (Hausarzt) und Überweisung zum MRT und Empfehlung zu uns. Aktuell Thrombembolieprophylaxe seit dem Unfall.. Mein rechtes Knie hat eine Schwellung, aber nicht so stark, dass es prall ist. Es gibt keine Überstreckung und auch kein Streckdefizit. Mein Knie ist angemessen beugbar, und es gibt keinen Druckschmerz an der inneren Seite des Knies, an der inneren Seite des Knies und an der äußeren Seite des Knies., Label: ['meniskus-urgent'], Loss: 16.11809539794922
# Sample 7715 - Features: 52.0 Jahre alt männlich seit 3-4 Monaten li. Kniebeschwerden; Beschwerden nach grösserer Belastung (Hausbau) Hühnerei große Schwellung Knieinnenseite; bisherige Therapie: keine; keine Schwellneigung; Instabilitätsgefühl, Label: ['other-minor'], Loss: 16.11809539794922
# Sample 4645 - Features: 52.0 Jahre alt weiblich Mitte Mai bei einer Fahrradtour starke Knieschwellung. Aktuell Beschwerden beim Treppe auf und ab gehen.. Mein rechtes Knie kann überstreckt werden, es gibt kein Streckdefizit. Die Beugung des Knies ist gut möglich. Mein Knie ist nicht gerötet. Es gibt leichten Druckschmerz auf der medialen Seite des Kniegelenks und stärkeren Druckschmerz am Pes Anserinus. Außerdem gibt es Druckschmerz an den Fettpolstern der Kniescheibe., Label: ['other-minor'], Loss: 16.11809539794922
# Sample 5312 - Features: 45.0 Jahre alt männlich . Mein linkes Knie hat keine Rötung, nur eine minimale Schwellung, und ich kann es nicht überstrecken. Das Streckdefizit ist gut, und die Beugung des Knies ist normal., Label: ['other-minor'], Loss: 16.11809539794922
# Sample 4432 - Features: 16.0 Jahre alt weiblich Patintin hat sich am 4.9.05 beim Volleyball das linke Knie verdreht; EB KH Kalk; nach NMR Klinik am Ring V.a. LCA-Ruptur;. Mein Gangbild ist flüssig, und es gibt keinen Schmerz beim Beckengeradruck. Mein linkes Knie kann nicht überstreckt werden und auch nicht komplett gestreckt werden. Die Beugung des Knies ist gut möglich. Klinisch gibt es keine Schwellung. Mein rechtes Knie kann auch nicht überstreckt werden und auch nicht komplett gestreckt werden. Die Beugung des Knies ist gut möglich. Klinisch gibt es auch keine Schwellung., Label: ['other-minor'], Loss: 16.11809539794922

# %%
df_train.iloc[6513]
# Out:
# Unnamed: 0.3                                                    6568
# Unnamed: 0.2                                                    6568
# Unnamed: 0.1                                                    6568
# Unnamed: 0                                                      3172
# patientid                                                    27596.0
# sex                                                             male
# age                                                             32.0
# ANA                Seit mehreren Monaten Gonalgie re.; Belastungs...
# EXA                re. Knie: physiologsche Beinachsen; Muskuläres...
# DIA_text            Z.n.arthroskopischer Chirurgie des Kniegelenkes.
# DIA_code                                                    M23.3- Z
# OP_text                                                          NaN
# OP_code                                                          NaN
# EXA_formatted      mässiger gelenkerguß, druckschmerz innereer se...
# EXA_interpreted    Mein Knie hat eine mäßige Schwellung, und es g...
# label                                                meniskus-urgent
# data               32.0 Jahre alt männlich Seit mehreren Monaten ...
# data2              Seit mehreren Monaten Gonalgie re.; Belastungs...
# Name: 6568, dtype: object

# %%
# Out:
# Model saved to ../models/lstm/final/final.h5
# Data saved

# %%
eval(model, test_padded, test_labels, label_encoder)
# Out:
# 246/246 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step
#   model  $accuracy$  $precision_{w}$  $recall_{w}$  $f1_{w}$  $f1_{mac}$
# 0              0.68             0.68          0.68      0.68        0.58
